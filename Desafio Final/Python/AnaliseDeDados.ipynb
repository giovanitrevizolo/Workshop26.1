# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from google.colab import files
print("Carregue o arquivo CSV:")
uploaded = files.upload()
# Out:
# Carregue o arquivo CSV:
#      <input type="file" id="files-9a1377cc-66fc-4854-bee2-92f412c5c7bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a1377cc-66fc-4854-bee2-92f412c5c7bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
df = pd.read_csv('academia_redfit.csv')

# %% [markdown]
# # **Tratamento dos dados**

# %%
df
# Out:
#      idade       sexo  frequencia_semanal_treino tipo_atividade  \
# 0       48      Outro                        7.0        Natação
# 1       30      Outro                        7.0           Yoga
# 2       35  Masculino                        5.0         Cardio
# 3       43      Outro                        3.0           Yoga
# 4       37  Masculino                        0.0       CrossFit
# ..     ...        ...                        ...            ...
# 995     43   Feminino                        0.0        Futebol
# 996     39      Outro                        5.0        Futebol
# 997     25   Feminino                        2.0        Natação
# 998     24  Masculino                        4.0       CrossFit
# 999     54  Masculino                        7.0           Yoga
#
#      tempo_medio_exercicio  minutos_totais_semana  preco_plano  \
# 0                     45.3                  317.1       188.47
# 1                     98.1                  686.7       198.07
# ...

# %%
df.describe()
# Out:
#              idade  frequencia_semanal_treino  tempo_medio_exercicio  \
# count  1000.000000                 949.000000             954.000000
# mean     40.811000                   3.559536              70.140776
# std      13.499612                   2.251555              29.475029
# min      18.000000                   0.000000              20.200000
# 25%      29.000000                   2.000000              44.525000
# 50%      41.000000                   4.000000              70.550000
# 75%      53.000000                   5.000000              95.200000
# max      64.000000                   7.000000             120.000000
#
#        minutos_totais_semana  preco_plano  primeiro_PGC   ultimo_PGC
# count             905.000000   1000.00000    1000.00000  1000.000000
# mean              247.515138    174.28306      25.06460    24.870300
# std               198.721094     70.96291       8.85659     8.743951
# min                 0.000000     50.05000      10.00000    10.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   idade                      1000 non-null   int64
#  1   sexo                       1000 non-null   object
#  2   frequencia_semanal_treino  949 non-null    float64
#  3   tipo_atividade             1000 non-null   object
#  4   tempo_medio_exercicio      954 non-null    float64
#  5   minutos_totais_semana      905 non-null    float64
#  6   preco_plano                1000 non-null   float64
#  7   possui_nutricionista       1000 non-null   object
#  8   primeiro_PGC               1000 non-null   float64
#  9   ultimo_PGC                 1000 non-null   float64
#  10  data_matricula             1000 non-null   object
#  11  estado                     1000 non-null   object
#  12  atividade                  1000 non-null   object
# ...

# %%
df['tipo_atividade'].unique()
# Out:
# array(['Natação', 'Yoga', 'Cardio', 'CrossFit', 'Musculação', 'Futebol',
#        'Natacao', 'Soccer', 'Fut', 'Swimming'], dtype=object)

# %%
mapa = {
    'Natação': 'Natação',
    'Natacao': 'Natação',
    'Swimming': 'Natação',

    'CrossFit': 'Musculação',
    'Musculação': 'Musculação',


    'Futebol': 'Futebol',
    'Fut': 'Futebol',
    'Soccer': 'Futebol',

    'Yoga': 'Outros',
    'Cardio': 'Outros',
}

# %%
df['atividade'] = df['tipo_atividade'].map(mapa)

df['atividade'].value_counts()
# Out:
# atividade
# Outros        376
# Musculação    324
# Futebol       156
# Natação       144
# Name: count, dtype: int64

# %%
df['sexo'].unique()
# Out:
# array(['Outro', 'Masculino', 'Feminino'], dtype=object)

# %%
df['estado'].unique()
# Out:
# array(['Ativa', 'Sedentária'], dtype=object)

# %%
df['data_matricula'] = pd.to_datetime(df['data_matricula'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   idade                      1000 non-null   int64
#  1   sexo                       1000 non-null   object
#  2   frequencia_semanal_treino  949 non-null    float64
#  3   tipo_atividade             1000 non-null   object
#  4   tempo_medio_exercicio      954 non-null    float64
#  5   minutos_totais_semana      905 non-null    float64
#  6   preco_plano                1000 non-null   float64
#  7   possui_nutricionista       1000 non-null   object
#  8   primeiro_PGC               1000 non-null   float64
#  9   ultimo_PGC                 1000 non-null   float64
#  10  data_matricula             1000 non-null   datetime64[ns]
#  11  estado                     1000 non-null   object
#  12  atividade                  1000 non-null   object
# ...

# %%
df['evolução_PGC'] = df['ultimo_PGC'] - df['primeiro_PGC']
df['evolução_PGC'].head()

# %%
plt.bar(df['possui_nutricionista'].value_counts().index , df['possui_nutricionista'].value_counts())
# Out:
# <BarContainer object of 2 artists>

# %%
plt.pie(df['sexo'].value_counts(),labels=labels, autopct='%1.1f%%')
plt.title('Sexo')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>
